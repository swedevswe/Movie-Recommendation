# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
movies = pd.read_csv("movies.csv")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
import re

def clean_title(title):
    return re.sub("[^a-zA-Z0-9 ]", "", title)

# %%
movies["clean_title"] = movies["title"].apply(clean_title)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
#build our search engine
#convert titles into sets of numbers for searching
#term frequency #inverse document frequency - unique search
#vector for each #compares set of numbers with the titles

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectoriser = TfidfVectorizer(ngram_range = (1,2))

tfidf = vectoriser.fit_transform(movies["clean_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(title):
    title = clean_title(title)
    query_vec = vectoriser.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = movies.iloc[indices][::-1]
    return results

# %%
pip install --upgrade ipywidgets jupyter notebook
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipywidgets

# %%
pip install notebook --upgrade
# Out:
# ...
#
# ...

# %%
#creating interactive widget to search and get results

import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value = "Toy Story",
    description = "Movie Title:",
    disabled = False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            display(search(title))
            
movie_input.observe(on_type, names='value')

# %%
display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()

# %%
ratings = pd.read_csv("ratings.csv")

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
#finding users who liked the same movie
movie_id = 1

# %%
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] >= 5)]["userId"].unique()

# %%
similar_users
# Out:
# array([    36,     75,     86, ..., 162518, 162519, 162530], dtype=int64)

# %%
similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] >= 4)]["movieId"]

# %%
similar_user_recs
# Out:
# 5101           1
# 5104          11
# 5105          34
# 5106          46
# 5108          60
#             ...
# 24998389    3735
# 24998390    3751
# 24998391    3763
# 24998392    4187
# 24998393    4321
# Name: movieId, Length: 1783202, dtype: int64

# %%
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

similar_user_recs = similar_user_recs[similar_user_recs > .1]

# %%
similar_user_recs
# Out:
# movieId
# 1       1.000000
# 260     0.521102
# 318     0.516733
# 356     0.502443
# 296     0.458315
#           ...
# 1358    0.101733
# 1485    0.101659
# 16      0.101140
# 899     0.100326
# 8874    0.100252
# Name: count, Length: 256, dtype: float64

# %%
#finding how much users like movies
all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]

# %%
all_users
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 19             1     2692     5.0  1147869100
# 29             1     4973     4.5  1147869080
# 48             1     7361     5.0  1147880055
# 72             2      110     5.0  1141416589
# ...          ...      ...     ...         ...
# 25000062  162541     5618     4.5  1240953299
# 25000065  162541     5952     5.0  1240952617
# 25000078  162541     7153     5.0  1240952613
# 25000081  162541     7361     4.5  1240953484
# 25000090  162541    50872     4.5  1240953372
#
# [2455054 rows x 4 columns]

# %%
all_users_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

# %%
all_users_recs
# Out:
# movieId
# 318     0.332559
# 296     0.276637
# 2571    0.237144
# 356     0.228624
# 593     0.219531
#           ...
# 2078    0.014215
# 1485    0.013025
# 2080    0.012825
# 1022    0.012214
# 708     0.010045
# Name: count, Length: 256, dtype: float64

# %%
#creating a recommendation score

rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis = 1)
rec_percentages.columns = ["similar", "all"]

# %%
rec_percentages
# Out:
#           similar       all
# movieId
# 1        1.000000  0.121207
# 260      0.521102  0.215934
# 318      0.516733  0.332559
# 356      0.502443  0.228624
# 296      0.458315  0.276637
# ...           ...       ...
# 1358     0.101733  0.029705
# 1485     0.101659  0.013025
# 16       0.101140  0.033154
# 899      0.100326  0.030747
# 8874     0.100252  0.044223
#
# [256 rows x 2 columns]

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

# %%
rec_percentages = rec_percentages.sort_values("score", ascending = False)

# %%
rec_percentages
# Out:
#           similar       all      score
# movieId
# 708      0.107878  0.010045  10.739077
# 2355     0.249889  0.024383  10.248480
# 2080     0.109211  0.012825   8.515203
# 1022     0.102473  0.012214   8.389772
# 1        1.000000  0.121207   8.250332
# ...           ...       ...        ...
# 58559    0.201392  0.142334   1.414925
# 7361     0.140234  0.101297   1.384388
# 79132    0.174219  0.127675   1.364553
# 4973     0.143492  0.109231   1.313651
# 2959     0.270324  0.210599   1.283599
#
# [256 rows x 3 columns]

# %%
rec_percentages.head(10).merge(movies, left_index = True, right_on="movieId")
# Out:
#        similar       all      score  movieId  \
# 693   0.107878  0.010045  10.739077      708
# 2264  0.249889  0.024383  10.248480     2355
# 1991  0.109211  0.012825   8.515203     2080
# 999   0.102473  0.012214   8.389772     1022
# 0     1.000000  0.121207   8.250332        1
# 435   0.135125  0.016558   8.160812      440
# 721   0.169776  0.021410   7.929787      736
# 1989  0.112691  0.014215   7.927372     2078
# 1     0.135940  0.017163   7.920634        2
# 588   0.117355  0.014827   7.915112      596
#
#                                     title  \
# 693   Truth About Cats & Dogs, The (1996)
# 2264                 Bug's Life, A (1998)
# 1991            Lady and the Tramp (1955)
# 999                     Cinderella (1950)
# 0                        Toy Story (1995)
# 435                           Dave (1993)
# 721                        Twister (1996)
# 1989              Jungle Book, The (1967)
# 1                          Jumanji (1995)
# ...

# %%
def find_similar_movies(movie_id):
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"]>4)]["movieId"]
    
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .10]
    
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

    rec_percentages = pd.concat([similar_user_recs, all_user_recs],axis=1)
    rec_percentages.columns = ["similar", "all"]

    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    
    rec_percentages = rec_percentages.sort_values("score", ascending = False)
    return rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")[["score", "title", "genres"]]

# %%
movie_input_name = widgets.Text(
    value = "Toy Story",
    description = "Movie Title:",
    disabled = False
)

recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title=data["new"]
        if len(title)>5:
            results = search(title)
            movie_id = results.iloc[0]["movieId"]
            display(find_similar_movies(movie_id))

movie_input_name.observe(on_type, names = "value")
display(movie_input_name, recommendation_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()
